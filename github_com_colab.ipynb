# %% [markdown]
# <a href="https://colab.research.google.com/github/douglasmaced0/base_dados_alunos/blob/main/github_com_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#        !git clone COLAR A URL

# !git clone https://github.com/douglasmaced0/base_dados_alunos
# Out:
# fatal: destination path 'base_dados_alunos' already exists and is not an empty directory.

# %%
# vamos contar quantos alunos temos

#1º saber onde esta o arquivo
#2º pedir que o python leia o arquivo
#3º contar e mostrar as informações

baseDados ="/content/base_dados_alunos/github - Página1.csv"

# usar uma função de abertura de arquivos
# with open(arquivo, método) as apelido
#métodos - leitura - "r" read
#métodos - lcolocar informações - "a" append
#métodos - deletar tudo e colocar de novo - "w" write

with open(baseDados, "r") as arquivo:
  qtd_linhas = arquivo.readlines()

print(len(qtd_linhas))
# Out:
# 53
